# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In This notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Some of the popular languages that Data Scientist use are :
# 1) R
# 2) SQL
# 3) Python

# %% [markdown]
# Some of the commonly used libraries used by Data Scientist include:
# 1) Numpy
# 2) Pandas
# 3) Matplotlib

# %% [markdown]
# | Data Science Tools |
# |-------------------:|
# | RStudio            |
# | Jupyter Notebooks  |
# | Visual Studio Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in python

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing it by 60
x = 200
min_to_hours = x/60
print(min_to_hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## **Objectives:**
# -  Save file as "DataScienceEcosystem" for reusability
# -  Define theme with the title " Data Science Tools and Ecosystem"
# -  Create a sentence to provide further detail about the lab's content
# -  Provide a summary of well known languages used by data scientists
# -  Provide a summary of the library used on those languages

# %% [markdown]
# ## Author
# Hector Rodrigo Munoz Cardozo

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
